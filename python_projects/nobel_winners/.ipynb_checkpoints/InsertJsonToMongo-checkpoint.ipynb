# %%
import pandas as pd
df = pd.read_json('/home/arindam/git/pythonstuff/python_projects/nobel_winners/nobel_winners_v2.json')

# %%
df.count()
# Out:
# born_in     1095
# category    1095
# country     1095
# link        1095
# name        1095
# text        1095
# year        1095
# dtype: int64

# %%
from pymongo import MongoClient
def get_mongo_database(db_name, host='localhost',\
                       port=27017, username=None, password=None):
    """ Get named database from MongoDB with/out authentication """
    # make Mongo connection with/out authentication
    if username and password:
        mongo_uri = 'mongodb://%s:%s@%s/%s'%\
        (username, password, host, db_name)
        conn = MongoClient(mongo_uri)
    else:
        conn = MongoClient(host, port)
    return conn[db_name]

# %%
import pandas as pd
from pymongo import MongoClient
def mongo_to_dataframe(db_name, collection, query={}, host='localhost', port=27017, username=None, password=None, no_id=True):
    """ create a dataframe from mongodb collection """
    db = get_mongo_database(db_name, host, port, username, password)
    cursor = db[collection].find(query)
    df = pd.DataFrame(list(cursor))
    if no_id:
        del df['_id']
    return df

# %%
def dataframe_to_mongo(df, db_name, collection,\
                        host='localhost', port=27017,\
                        username=None, password=None):
    """ save a dataframe to mongodb collection """
    db = get_mongo_database(db_name, host, port, username,\
                            password)
    records = df.to_dict('records')
    db[collection].insert_many(records)

# %%
dataframe_to_mongo(df, 'nobel_prize', 'winners')

# %%
mongo_to_dataframe('nobel_prize', 'winners')
# Out:
#         born_in                category        country  \
# 0                Physiology or Medicine      Argentina
# 1                                 Peace      Argentina
# 2                             Chemistry      Argentina
# 3                Physiology or Medicine      Argentina
# 4                                 Peace      Argentina
# 5                               Physics      Australia
# 6     Australia  Physiology or Medicine
# 7                Physiology or Medicine      Australia
# 8                Physiology or Medicine      Australia
# 9                Physiology or Medicine      Australia
# 10                            Economics      Australia
# 11    Australia               Chemistry
# 12                           Literature      Australia
# 13               Physiology or Medicine      Australia
# 14               Physiology or Medicine      Australia
# 15               Physiology or Medicine      Australia
# 16                              Physics      Australia
# 17      Austria               Chemistry
# 18                                Peace        Austria
# 19                           Literature        Austria
# 20      Austria  Physiology or Medicine
# 21      Austria               Chemistry
# 22                            Economics        Austria
# 23               Physiology or Medicine        Austria
# 24      Austria  Physiology or Medicine
# 25                            Chemistry        Austria
# 26                              Physics        Austria
# 27      Austria               Chemistry
# 28      Austria  Physiology or Medicine
# 29                              Physics        Austria
# ...         ...                     ...            ...
# 1065             Physiology or Medicine  United States
# 1066             Physiology or Medicine  United States
# 1067                            Physics  United States
# 1068             Physiology or Medicine  United States
# 1069                            Physics  United States
# 1070                         Literature  United States
# 1071                            Physics  United States
# 1072                         Literature  United States
# 1073                            Physics  United States
# 1074                          Chemistry  United States
# 1075             Physiology or Medicine  United States
# 1076             Physiology or Medicine  United States
# 1077             Physiology or Medicine  United States
# 1078             Physiology or Medicine  United States
# 1079                          Chemistry  United States
# 1080                              Peace  United States
# 1081                              Peace  United States
# 1082                         Literature  United States
# 1083                              Peace  United States
# 1084                            Physics  United States
# 1085                              Peace  United States
# 1086                            Physics  United States
# 1087                              Peace  United States
# 1088                          Chemistry  United States
# 1089                              Peace  United States
# 1090                            Physics  United States
# 1091                              Peace  United States
# 1092             Physiology or Medicine      Venezuela
# 1093                              Peace        Vietnam
# 1094                              Peace          Yemen
#
#                                                    link  \
# 0      http://en.wikipedia.org/wiki/C%C3%A9sar_Milstein
# 1     http://en.wikipedia.org/wiki/Adolfo_P%C3%A9rez