# %%
import requests

# %%
req = requests.get('http://localhost:5000/api/v1/lag_times')

# %%
req.json()
# Out:
# [{u'reading_date_time': u'2018-08-05 00:00:32', u'reading_lag_time': 3},
#  {u'reading_date_time': u'2018-08-05 00:01:32', u'reading_lag_time': 13},
#  {u'reading_date_time': u'2018-08-05 00:02:32', u'reading_lag_time': 17},
#  {u'reading_date_time': u'2018-08-05 00:03:32', u'reading_lag_time': 30},
#  {u'reading_date_time': u'2018-08-05 00:04:32', u'reading_lag_time': 28},
#  {u'reading_date_time': u'2018-08-05 00:05:32', u'reading_lag_time': 0},
#  {u'reading_date_time': u'2018-08-05 00:06:32', u'reading_lag_time': 1},
#  {u'reading_date_time': u'2018-08-05 00:07:32', u'reading_lag_time': 1},
#  {u'reading_date_time': u'2018-08-05 00:08:32', u'reading_lag_time': 1},
#  {u'reading_date_time': u'2018-08-05 00:09:32', u'reading_lag_time': 0},
#  {u'reading_date_time': u'2018-08-05 00:10:32', u'reading_lag_time': 0},
#  {u'reading_date_time': u'2018-08-05 00:11:32', u'reading_lag_time': 10},
#  {u'reading_date_time': u'2018-08-05 00:12:32', u'reading_lag_time': 6},
# ...
