# %%
import requests

# %%
req = requests.get('http://localhost:5000/api/v1/lag_times')

# %%
req.json()
# Out:
# [{u'reading_date_time': u'2018-08-06 00:00:56', u'reading_lag_time': 10},
#  {u'reading_date_time': u'2018-08-06 00:01:56', u'reading_lag_time': 3},
#  {u'reading_date_time': u'2018-08-06 00:02:56', u'reading_lag_time': 45},
#  {u'reading_date_time': u'2018-08-06 00:03:56', u'reading_lag_time': 27},
#  {u'reading_date_time': u'2018-08-06 00:04:56', u'reading_lag_time': 27},
#  {u'reading_date_time': u'2018-08-06 00:05:56', u'reading_lag_time': 10},
#  {u'reading_date_time': u'2018-08-06 00:06:56', u'reading_lag_time': 1},
#  {u'reading_date_time': u'2018-08-06 00:07:56', u'reading_lag_time': 2},
#  {u'reading_date_time': u'2018-08-06 00:08:56', u'reading_lag_time': 1},
#  {u'reading_date_time': u'2018-08-06 00:09:56', u'reading_lag_time': 2},
#  {u'reading_date_time': u'2018-08-06 00:10:56', u'reading_lag_time': 0},
#  {u'reading_date_time': u'2018-08-06 00:11:56', u'reading_lag_time': 1},
#  {u'reading_date_time': u'2018-08-06 00:12:56', u'reading_lag_time': 0},
# ...
