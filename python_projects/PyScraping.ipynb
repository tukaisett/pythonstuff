# %%
from bs4 import BeautifulSoup
import requests
BASE_URL = 'http://en.wikipedia.org'
# Wikipedia will reject our request unless we add
# a 'User-Agent' attribute to our http header.
HEADERS = {'User-Agent': 'Mozilla/5.0'}
def get_Nobel_soup():
    """ Return a parsed tag tree of our Nobel prize page """
    # Make a request to the Nobel page, setting valid headers
    response = requests.get(
    BASE_URL + '/wiki/List_of_Nobel_laureates',
    headers=HEADERS)
    # Return the content of the response parsed by BeautifulSoup
    return BeautifulSoup(response.content, "lxml")

# %%
soup = get_Nobel_soup()

# %%
soup.find('table', {'class':'wikitable sortable'})
# Out:
# <table class="wikitable sortable">\n<tbody><tr>\n<th>Year\n</th>\n<th width="18%"><a href="/wiki/List_of_Nobel_laureates_in_Physics" title="List of Nobel laureates in Physics">Physics</a>\n</th>\n<th width="16%"><a href="/wiki/List_of_Nobel_laureates_in_Chemistry" title="List of Nobel laureates in Chemistry">Chemistry</a>\n</th>\n<th width="18%"><a href="/wiki/List_of_Nobel_laureates_in_Physiology_or_Medicine" title="List of Nobel laureates in Physiology or Medicine">Physiology<br/>or Medicine</a>\n</th>\n<th width="16%"><a href="/wiki/List_of_Nobel_laureates_in_Literature" title="List of Nobel laureates in Literature">Literature</a>\n</th>\n<th width="16%"><a href="/wiki/List_of_Nobel_Peace_Prize_laureates" title="List of Nobel Peace Prize laureates">Peace</a>\n</th>\n<th width="15%"><a class="mw-redirect" href="/wiki/List_of_Nobel_laureates_in_Economics" title="List of Nobel laureates in Economics">Economics</a>\n</th></tr>\n<tr>\n<td align="center">1901\n</td>\n<td><span data-sort-value="R\xf6ntgen, Wilhelm"><span class="vcard"><span class="fn"><a href="/wiki/Wilhelm_R%C3%B6ntgen" title="Wilhelm R\xf6ntgen">Wilhelm R\xf6ntgen</a></span></span></span>\n</td>\n<td><span data-sort-value="Hoff, Jacobus Henricus van 't"><span class="vcard"><span class="fn"><a href="/wiki/Jacobus_Henricus_van_%27t_Hoff" title="Jacobus Henricus van 't Hoff">Jacobus Henricus van 't Hoff</a></span></span></span>\n</td>\n<td><span data-sort-value="von Behring, Emil Adolf"><span class="vcard"><span class="fn"><a class="mw-redirect" href="/wiki/Emil_Adolf_von_Behring" title="Emil Adolf von Behring">Emil Adolf von Behring</a></span></span></span>\n</td>\n<td><span data-sort-value="Prudhomme, Sully"><span class="vcard"><span class="fn"><a href="/wiki/Sully_Prudhomme" title="Sully Prudhomme">Sully Prudhomme</a></span></span></span>\n</td>\n<td><span data-sort-value="Dunant, Henry"><span class="vcard"><span class="fn"><a href="/wiki/Henry_Dunant" title="Henry Dunant">Henry Dunant</a></span></span></span>;<br/><span data-sort-value="Passy, Fr\xe9d\xe9ric"><span class="vcard"><span class="fn"><a href="/wiki/Fr%C3%A9d%C3%A9ric_Passy" title="Fr\xe9d\xe9ric Passy">Fr\xe9d\xe9ric Passy</a></span></span></span>\n</td>\n<td align="center">\u2014\n</td></tr>\n<tr>\n<td align="center">1902\n</td>\n<td><span data-sort-value="Lorentz, Hendrik"><span class="vcard"><span class="fn"><a href="/wiki/Hendrik_Lorentz" title="Hendrik Lorentz">Hendrik Lorentz</a></span></span></span>;<br/><span data-sort-value="Zeeman, Pieter"><span class="vcard"><span class="fn"><a href="/wiki/Pieter_Zeeman" title="Pieter Zeeman">Pieter Zeeman</a></span></span></span>\n</td>\n<td><span data-sort-value="Fischer, Hermann Emil"><span class="vcard"><span class="fn"><a href="/wiki/Hermann_Emil_Fischer" title="Hermann Emil Fischer">Hermann Emil Fischer</a></span></span></span>\n</td>\n<td><span data-sort-value="Ross, Ronald"><span class="vcard"><span class="fn"><a href="/wiki/Ronald_Ross" title="Ronald Ross">Ronald Ross</a></span></span></span>\n</td>\n<td><span data-sort-value="Mommsen, Theodor"><span class="vcard"><span class="fn"><a href="/wiki/Theodor_Mommsen" title="Theodor Mommsen">Theodor Mommsen</a></span></span></span>\n</td>\n<td><span data-sort-value="Ducommun, \xc9lie"><span class="vcard"><span class="fn"><a href="/wiki/%C3%89lie_Ducommun" title="\xc9lie Ducommun">\xc9lie Ducommun</a></span></span></span>;<br/><span data-sort-value="Gobat, Charles Albert"><span class="vcard"><span class="fn"><a href="/wiki/Charles_Albert_Gobat" title="Charles Albert Gobat">Charles Albert Gobat</a></span></span></span>\n</td>\n<td align="center">\u2014\n</td></tr>\n<tr>\n<td align="center">1903\n</td>\n<td><span data-sort-value="Becquerel, Henri"><span class="vcard"><span class="fn"><a href="/wiki/Henri_Becquerel" title="Henri Becquerel">Henri Becquerel</a></span></span></span>;<br/><span data-sort-value="Curie, Pierre"><span class="vcard"><span class="fn"><a href="/wiki/Pierre_Curie" title="Pierre Curie ...

# %%
def get_column_titles(table):
    """ Get the Nobel categories from the table header """
    cols = []
    for th in table.select_one('tr').select('th')[1:]:
        link = th.select_one('a')
        # Store the category name and any Wikipedia link it has
        if link:
            cols.append({'name':link.text,\
                        'href':link.attrs['href']})
        else:
            cols.append({'name':th.text, 'href':None})
    return cols

# %%
table = soup.select_one('table.sortable.wikitable')
get_column_titles(table)
# Out:
# [{'href': '/wiki/List_of_Nobel_laureates_in_Physics', 'name': u'Physics'},
#  {'href': '/wiki/List_of_Nobel_laureates_in_Chemistry', 'name': u'Chemistry'},
#  {'href': '/wiki/List_of_Nobel_laureates_in_Physiology_or_Medicine',
#   'name': u'Physiologyor Medicine'},
#  {'href': '/wiki/List_of_Nobel_laureates_in_Literature',
#   'name': u'Literature'},
#  {'href': '/wiki/List_of_Nobel_Peace_Prize_laureates', 'name': u'Peace'},
#  {'href': '/wiki/List_of_Nobel_laureates_in_Economics', 'name': u'Economics'}]

# %%
def get_Nobel_winners(table):
    cols = get_column_titles(table)
    winners = []
    for row in table.select('tr')[1:-1]:
        ## year = int(row.select_one('td').text) # Gets 1st <td>
        year = int(row.select_one('td').text[0:4])
        ##year = row.select_one('td').text
        for i, td in enumerate(row.select('td')[1:]):
            for winner in td.select('a'):
                href = winner.attrs['href']
                if not href.startswith('#endnote'):
                    winners.append({
                        'year':year,
                        'category':cols[i]['name'],
                        'name':winner.text,
                        'link':winner.attrs['href']
                    })
    return winners

# %%
get_Nobel_winners(table)
# Out:
# [{'category': u'Physics',
#   'link': '/wiki/Wilhelm_R%C3%B6ntgen',
#   'name': u'Wilhelm R\xf6ntgen',
#   'year': 1901},
#  {'category': u'Chemistry',
#   'link': '/wiki/Jacobus_Henricus_van_%27t_Hoff',
#   'name': u"Jacobus Henricus van 't Hoff",
#   'year': 1901},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Emil_Adolf_von_Behring',
#   'name': u'Emil Adolf von Behring',
#   'year': 1901},
#  {'category': u'Literature',
#   'link': '/wiki/Sully_Prudhomme',
#   'name': u'Sully Prudhomme',
#   'year': 1901},
#  {'category': u'Peace',
#   'link': '/wiki/Henry_Dunant',
#   'name': u'Henry Dunant',
#   'year': 1901},
#  {'category': u'Peace',
#   'link': '/wiki/Fr%C3%A9d%C3%A9ric_Passy',
#   'name': u'Fr\xe9d\xe9ric Passy',
#   'year': 1901},
#  {'category': u'Physics',
#   'link': '/wiki/Hendrik_Lorentz',
#   'name': u'Hendrik Lorentz',
#   'year': 1902},
#  {'category': u'Physics',
#   'link': '/wiki/Pieter_Zeeman',
#   'name': u'Pieter Zeeman',
#   'year': 1902},
#  {'category': u'Chemistry',
#   'link': '/wiki/Hermann_Emil_Fischer',
#   'name': u'Hermann Emil Fischer',
#   'year': 1902},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Ronald_Ross',
#   'name': u'Ronald Ross',
#   'year': 1902},
#  {'category': u'Literature',
#   'link': '/wiki/Theodor_Mommsen',
#   'name': u'Theodor Mommsen',
#   'year': 1902},
#  {'category': u'Peace',
#   'link': '/wiki/%C3%89lie_Ducommun',
#   'name': u'\xc9lie Ducommun',
#   'year': 1902},
#  {'category': u'Peace',
#   'link': '/wiki/Charles_Albert_Gobat',
#   'name': u'Charles Albert Gobat',
#   'year': 1902},
#  {'category': u'Physics',
#   'link': '/wiki/Henri_Becquerel',
#   'name': u'Henri Becquerel',
#   'year': 1903},
#  {'category': u'Physics',
#   'link': '/wiki/Pierre_Curie',
#   'name': u'Pierre Curie',
#   'year': 1903},
#  {'category': u'Physics',
#   'link': '/wiki/Marie_Curie',
#   'name': u'Marie Curie',
#   'year': 1903},
#  {'category': u'Chemistry',
#   'link': '/wiki/Svante_Arrhenius',
#   'name': u'Svante Arrhenius',
#   'year': 1903},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Niels_Ryberg_Finsen',
#   'name': u'Niels Ryberg Finsen',
#   'year': 1903},
#  {'category': u'Literature',
#   'link': '/wiki/Bj%C3%B8rnstjerne_Bj%C3%B8rnson',
#   'name': u'Bj\xf8rnstjerne Bj\xf8rnson',
#   'year': 1903},
#  {'category': u'Peace',
#   'link': '/wiki/Randal_Cremer',
#   'name': u'Randal Cremer',
#   'year': 1903},
#  {'category': u'Physics',
#   'link': '/wiki/John_Strutt,_3rd_Baron_Rayleigh',
#   'name': u'Lord Rayleigh',
#   'year': 1904},
#  {'category': u'Chemistry',
#   'link': '/wiki/William_Ramsay',
#   'name': u'William Ramsay',
#   'year': 1904},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Ivan_Pavlov',
#   'name': u'Ivan Pavlov',
#   'year': 1904},
#  {'category': u'Literature',
#   'link': '/wiki/Fr%C3%A9d%C3%A9ric_Mistral',
#   'name': u'Fr\xe9d\xe9ric Mistral',
#   'year': 1904},
#  {'category': u'Literature',
#   'link': '/wiki/Jos%C3%A9_Echegaray',
#   'name': u'Jos\xe9 Echegaray',
#   'year': 1904},
#  {'category': u'Peace',
#   'link': '/wiki/Institut_de_Droit_International',
#   'name': u'Institut de Droit International',
#   'year': 1904},
#  {'category': u'Physics',
#   'link': '/wiki/Philipp_Lenard',
#   'name': u'Philipp Lenard',
#   'year': 1905},
#  {'category': u'Chemistry',
#   'link': '/wiki/Adolf_von_Baeyer',
#   'name': u'Adolf von Baeyer',
#   'year': 1905},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Robert_Koch',
#   'name': u'Robert Koch',
#   'year': 1905},
#  {'category': u'Literature',
#   'link': '/wiki/Henryk_Sienkiewicz',
#   'name': u'Henryk Sienkiewicz',
#   'year': 1905},
#  {'category': u'Peace',
#   'link': '/wiki/Bertha_von_Suttner',
#   'name': u'Bertha von Suttner',
#   'year': 1905},
#  {'category': u'Physics',
#   'link': '/wiki/J._J._Thomson',
#   'name': u'J. J. Thomson',
#   'year': 1906},
#  {'category': u'Chemistry',
#   'link': '/wiki/Henri_Moissan',
#   'name': u'Henri Moissan',
#   'year': 1906},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Camillo_Golgi',
#   'name': u'Camillo Golgi',
#   'year': 1906},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Santiago_Ram%C3%B3n_y_Cajal',
#   'name': u'Santiago Ram\xf3n y Cajal',
#   'year': 1906},
#  {'category': u'Literature',
#   'link': '/wiki/Giosu%C3%A8_Carducci',
#   'name': u'Giosu\xe8 Carducci',
#   'year': 1906},
#  {'category': u'Peace',
#   'link': '/wiki/Theodore_Roosevelt',
#   'name': u'Theodore Roosevelt',
#   'year': 1906},
#  {'category': u'Physics',
#   'link': '/wiki/Albert_Abraham_Michelson',
#   'name': u'Albert Abraham Michelson',
#   'year': 1907},
#  {'category': u'Chemistry',
#   'link': '/wiki/Eduard_Buchner',
#   'name': u'Eduard Buchner',
#   'year': 1907},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Charles_Louis_Alphonse_Laveran',
#   'name': u'Charles Louis Alphonse Laveran',
#   'year': 1907},
#  {'category': u'Literature',
#   'link': '/wiki/Rudyard_Kipling',
#   'name': u'Rudyard Kipling',
#   'year': 1907},
#  {'category': u'Peace',
#   'link': '/wiki/Ernesto_Teodoro_Moneta',
#   'name': u'Ernesto Teodoro Moneta',
#   'year': 1907},
#  {'category': u'Peace',
#   'link': '/wiki/Louis_Renault_(jurist)',
#   'name': u'Louis Renault',
#   'year': 1907},
#  {'category': u'Physics',
#   'link': '/wiki/Gabriel_Lippmann',
#   'name': u'Gabriel Lippmann',
#   'year': 1908},
#  {'category': u'Chemistry',
#   'link': '/wiki/Ernest_Rutherford',
#   'name': u'Ernest Rutherford',
#   'year': 1908},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/%C3%89lie_Metchnikoff',
#   'name': u'\xc9lie Metchnikoff',
#   'year': 1908},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Paul_Ehrlich',
#   'name': u'Paul Ehrlich',
#   'year': 1908},
#  {'category': u'Literature',
#   'link': '/wiki/Rudolf_Christoph_Eucken',
#   'name': u'Rudolf Christoph Eucken',
#   'year': 1908},
#  {'category': u'Peace',
#   'link': '/wiki/Klas_Pontus_Arnoldson',
#   'name': u'Klas Pontus Arnoldson',
#   'year': 1908},
#  {'category': u'Peace',
#   'link': '/wiki/Fredrik_Bajer',
#   'name': u'Fredrik Bajer',
#   'year': 1908},
#  {'category': u'Physics',
#   'link': '/wiki/Karl_Ferdinand_Braun',
#   'name': u'Karl Ferdinand Braun',
#   'year': 1909},
#  {'category': u'Physics',
#   'link': '/wiki/Guglielmo_Marconi',
#   'name': u'Guglielmo Marconi',
#   'year': 1909},
#  {'category': u'Chemistry',
#   'link': '/wiki/Wilhelm_Ostwald',
#   'name': u'Wilhelm Ostwald',
#   'year': 1909},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Emil_Theodor_Kocher',
#   'name': u'Emil Theodor Kocher',
#   'year': 1909},
#  {'category': u'Literature',
#   'link': '/wiki/Selma_Lagerl%C3%B6f',
#   'name': u'Selma Lagerl\xf6f',
#   'year': 1909},
#  {'category': u'Peace',
#   'link': '/wiki/Auguste_Marie_Fran%C3%A7ois_Beernaert',
#   'name': u'Auguste Marie Fran\xe7ois Beernaert',
#   'year': 1909},
#  {'category': u'Peace',
#   'link': '/wiki/Paul-Henri-Benjamin_d%27Estournelles_de_Constant',
#   'name': u"Paul-Henri-Benjamin d'Estournelles de Constant",
#   'year': 1909},
#  {'category': u'Physics',
#   'link': '/wiki/Johannes_Diderik_van_der_Waals',
#   'name': u'Johannes Diderik van der Waals',
#   'year': 1910},
#  {'category': u'Chemistry',
#   'link': '/wiki/Otto_Wallach',
#   'name': u'Otto Wallach',
#   'year': 1910},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Albrecht_Kossel',
#   'name': u'Albrecht Kossel',
#   'year': 1910},
#  {'category': u'Literature',
#   'link': '/wiki/Paul_Heyse',
#   'name': u'Paul Heyse',
#   'year': 1910},
#  {'category': u'Peace',
#   'link': '/wiki/International_Peace_Bureau',
#   'name': u'International Peace Bureau',
#   'year': 1910},
#  {'category': u'Physics',
#   'link': '/wiki/Wilhelm_Wien',
#   'name': u'Wilhelm Wien',
#   'year': 1911},
#  {'category': u'Chemistry',
#   'link': '/wiki/Marie_Sk%C5%82odowska-Curie',
#   'name': u'Marie Sk\u0142odowska-Curie',
#   'year': 1911},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Allvar_Gullstrand',
#   'name': u'Allvar Gullstrand',
#   'year': 1911},
#  {'category': u'Literature',
#   'link': '/wiki/Maurice_Maeterlinck',
#   'name': u'Maurice Maeterlinck',
#   'year': 1911},
#  {'category': u'Peace',
#   'link': '/wiki/Tobias_Asser',
#   'name': u'Tobias Asser',
#   'year': 1911},
#  {'category': u'Peace',
#   'link': '/wiki/Alfred_Hermann_Fried',
#   'name': u'Alfred Hermann Fried',
#   'year': 1911},
#  {'category': u'Physics',
#   'link': '/wiki/Gustaf_Dal%C3%A9n',
#   'name': u'Gustaf Dal\xe9n',
#   'year': 1912},
#  {'category': u'Chemistry',
#   'link': '/wiki/Victor_Grignard',
#   'name': u'Victor Grignard',
#   'year': 1912},
#  {'category': u'Chemistry',
#   'link': '/wiki/Paul_Sabatier_(chemist)',
#   'name': u'Paul Sabatier',
#   'year': 1912},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Alexis_Carrel',
#   'name': u'Alexis Carrel',
#   'year': 1912},
#  {'category': u'Literature',
#   'link': '/wiki/Gerhart_Hauptmann',
#   'name': u'Gerhart Hauptmann',
#   'year': 1912},
#  {'category': u'Peace',
#   'link': '/wiki/Elihu_Root',
#   'name': u'Elihu Root',
#   'year': 1912},
#  {'category': u'Physics',
#   'link': '/wiki/Heike_Kamerlingh_Onnes',
#   'name': u'Heike Kamerlingh Onnes',
#   'year': 1913},
#  {'category': u'Chemistry',
#   'link': '/wiki/Alfred_Werner',
#   'name': u'Alfred Werner',
#   'year': 1913},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Charles_Richet',
#   'name': u'Charles Richet',
#   'year': 1913},
#  {'category': u'Literature',
#   'link': '/wiki/Rabindranath_Tagore',
#   'name': u'Rabindranath Tagore',
#   'year': 1913},
#  {'category': u'Peace',
#   'link': '/wiki/Henri_La_Fontaine',
#   'name': u'Henri La Fontaine',
#   'year': 1913},
#  {'category': u'Physics',
#   'link': '/wiki/Max_von_Laue',
#   'name': u'Max von Laue',
#   'year': 1914},
#  {'category': u'Chemistry',
#   'link': '/wiki/Theodore_William_Richards',
#   'name': u'Theodore William Richards',
#   'year': 1914},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Robert_B%C3%A1r%C3%A1ny',
#   'name': u'Robert B\xe1r\xe1ny',
#   'year': 1914},
#  {'category': u'Physics',
#   'link': '/wiki/William_Henry_Bragg',
#   'name': u'William Henry Bragg',
#   'year': 1915},
#  {'category': u'Physics',
#   'link': '/wiki/William_Lawrence_Bragg',
#   'name': u'William Lawrence Bragg',
#   'year': 1915},
#  {'category': u'Chemistry',
#   'link': '/wiki/Richard_Willst%C3%A4tter',
#   'name': u'Richard Willst\xe4tter',
#   'year': 1915},
#  {'category': u'Literature',
#   'link': '/wiki/Romain_Rolland',
#   'name': u'Romain Rolland',
#   'year': 1915},
#  {'category': u'Literature',
#   'link': '/wiki/Verner_von_Heidenstam',
#   'name': u'Verner von Heidenstam',
#   'year': 1916},
#  {'category': u'Physics',
#   'link': '/wiki/Charles_Glover_Barkla',
#   'name': u'Charles Glover Barkla',
#   'year': 1917},
#  {'category': u'Literature',
#   'link': '/wiki/Karl_Adolph_Gjellerup',
#   'name': u'Karl Adolph Gjellerup',
#   'year': 1917},
#  {'category': u'Literature',
#   'link': '/wiki/Henrik_Pontoppidan',
#   'name': u'Henrik Pontoppidan',
#   'year': 1917},
#  {'category': u'Peace',
#   'link': '/wiki/International_Committee_of_the_Red_Cross',
#   'name': u'International Committee of the Red Cross',
#   'year': 1917},
#  {'category': u'Physics',
#   'link': '/wiki/Max_Planck',
#   'name': u'Max Planck',
#   'year': 1918},
#  {'category': u'Chemistry',
#   'link': '/wiki/Fritz_Haber',
#   'name': u'Fritz Haber',
#   'year': 1918},
#  {'category': u'Physics',
#   'link': '/wiki/Johannes_Stark',
#   'name': u'Johannes Stark',
#   'year': 1919},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Jules_Bordet',
#   'name': u'Jules Bordet',
#   'year': 1919},
#  {'category': u'Literature',
#   'link': '/wiki/Carl_Spitteler',
#   'name': u'Carl Spitteler',
#   'year': 1919},
#  {'category': u'Peace',
#   'link': '/wiki/Woodrow_Wilson',
#   'name': u'Woodrow Wilson',
#   'year': 1919},
#  {'category': u'Physics',
#   'link': '/wiki/Charles_%C3%89douard_Guillaume',
#   'name': u'Charles \xc9douard Guillaume',
#   'year': 1920},
#  {'category': u'Chemistry',
#   'link': '/wiki/Walther_Nernst',
#   'name': u'Walther Nernst',
#   'year': 1920},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/August_Krogh',
#   'name': u'August Krogh',
#   'year': 1920},
#  {'category': u'Literature',
#   'link': '/wiki/Knut_Hamsun',
#   'name': u'Knut Hamsun',
#   'year': 1920},
#  {'category': u'Peace',
#   'link': '/wiki/L%C3%A9on_Bourgeois',
#   'name': u'L\xe9on Bourgeois',
#   'year': 1920},
#  {'category': u'Physics',
#   'link': '/wiki/Albert_Einstein',
#   'name': u'Albert Einstein',
#   'year': 1921},
#  {'category': u'Chemistry',
#   'link': '/wiki/Frederick_Soddy',
#   'name': u'Frederick Soddy',
#   'year': 1921},
#  {'category': u'Literature',
#   'link': '/wiki/Anatole_France',
#   'name': u'Anatole France',
#   'year': 1921},
#  {'category': u'Peace',
#   'link': '/wiki/Hjalmar_Branting',
#   'name': u'Hjalmar Branting',
#   'year': 1921},
#  {'category': u'Peace',
#   'link': '/wiki/Christian_Lous_Lange',
#   'name': u'Christian Lous Lange',
#   'year': 1921},
#  {'category': u'Physics',
#   'link': '/wiki/Niels_Bohr',
#   'name': u'Niels Bohr',
#   'year': 1922},
#  {'category': u'Chemistry',
#   'link': '/wiki/Francis_William_Aston',
#   'name': u'Francis William Aston',
#   'year': 1922},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Archibald_Hill',
#   'name': u'Archibald Hill',
#   'year': 1922},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Otto_Fritz_Meyerhof',
#   'name': u'Otto Fritz Meyerhof',
#   'year': 1922},
#  {'category': u'Literature',
#   'link': '/wiki/Jacinto_Benavente',
#   'name': u'Jacinto Benavente',
#   'year': 1922},
#  {'category': u'Peace',
#   'link': '/wiki/Fridtjof_Nansen',
#   'name': u'Fridtjof Nansen',
#   'year': 1922},
#  {'category': u'Physics',
#   'link': '/wiki/Robert_Andrews_Millikan',
#   'name': u'Robert Andrews Millikan',
#   'year': 1923},
#  {'category': u'Chemistry',
#   'link': '/wiki/Fritz_Pregl',
#   'name': u'Fritz Pregl',
#   'year': 1923},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Frederick_Banting',
#   'name': u'Frederick Banting',
#   'year': 1923},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/John_James_Rickard_Macleod',
#   'name': u'John James Rickard Macleod',
#   'year': 1923},
#  {'category': u'Literature',
#   'link': '/wiki/W._B._Yeats',
#   'name': u'W. B. Yeats',
#   'year': 1923},
#  {'category': u'Physics',
#   'link': '/wiki/Manne_Siegbahn',
#   'name': u'Manne Siegbahn',
#   'year': 1924},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Willem_Einthoven',
#   'name': u'Willem Einthoven',
#   'year': 1924},
#  {'category': u'Literature',
#   'link': '/wiki/W%C5%82adys%C5%82aw_Reymont',
#   'name': u'W\u0142adys\u0142aw Reymont',
#   'year': 1924},
#  {'category': u'Physics',
#   'link': '/wiki/James_Franck',
#   'name': u'James Franck',
#   'year': 1925},
#  {'category': u'Physics',
#   'link': '/wiki/Gustav_Ludwig_Hertz',
#   'name': u'Gustav Ludwig Hertz',
#   'year': 1925},
#  {'category': u'Chemistry',
#   'link': '/wiki/Richard_Adolf_Zsigmondy',
#   'name': u'Richard Adolf Zsigmondy',
#   'year': 1925},
#  {'category': u'Literature',
#   'link': '/wiki/George_Bernard_Shaw',
#   'name': u'George Bernard Shaw',
#   'year': 1925},
#  {'category': u'Peace',
#   'link': '/wiki/Austen_Chamberlain',
#   'name': u'Austen Chamberlain',
#   'year': 1925},
#  {'category': u'Peace',
#   'link': '/wiki/Charles_G._Dawes',
#   'name': u'Charles G. Dawes',
#   'year': 1925},
#  {'category': u'Physics',
#   'link': '/wiki/Jean_Baptiste_Perrin',
#   'name': u'Jean Baptiste Perrin',
#   'year': 1926},
#  {'category': u'Chemistry',
#   'link': '/wiki/Theodor_Svedberg',
#   'name': u'Theodor Svedberg',
#   'year': 1926},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Johannes_Fibiger',
#   'name': u'Johannes Fibiger',
#   'year': 1926},
#  {'category': u'Literature',
#   'link': '/wiki/Grazia_Deledda',
#   'name': u'Grazia Deledda',
#   'year': 1926},
#  {'category': u'Peace',
#   'link': '/wiki/Aristide_Briand',
#   'name': u'Aristide Briand',
#   'year': 1926},
#  {'category': u'Peace',
#   'link': '/wiki/Gustav_Stresemann',
#   'name': u'Gustav Stresemann',
#   'year': 1926},
#  {'category': u'Physics',
#   'link': '/wiki/Arthur_Compton',
#   'name': u'Arthur Compton',
#   'year': 1927},
#  {'category': u'Physics',
#   'link': '/wiki/Charles_Thomson_Rees_Wilson',
#   'name': u'Charles Thomson Rees Wilson',
#   'year': 1927},
#  {'category': u'Chemistry',
#   'link': '/wiki/Heinrich_Otto_Wieland',
#   'name': u'Heinrich Otto Wieland',
#   'year': 1927},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Julius_Wagner-Jauregg',
#   'name': u'Julius Wagner-Jauregg',
#   'year': 1927},
#  {'category': u'Literature',
#   'link': '/wiki/Henri_Bergson',
#   'name': u'Henri Bergson',
#   'year': 1927},
#  {'category': u'Peace',
#   'link': '/wiki/Ferdinand_Buisson',
#   'name': u'Ferdinand Buisson',
#   'year': 1927},
#  {'category': u'Peace',
#   'link': '/wiki/Ludwig_Quidde',
#   'name': u'Ludwig Quidde',
#   'year': 1927},
#  {'category': u'Physics',
#   'link': '/wiki/Owen_Willans_Richardson',
#   'name': u'Owen Willans Richardson',
#   'year': 1928},
#  {'category': u'Chemistry',
#   'link': '/wiki/Adolf_Otto_Reinhold_Windaus',
#   'name': u'Adolf Otto Reinhold Windaus',
#   'year': 1928},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Charles_Nicolle',
#   'name': u'Charles Nicolle',
#   'year': 1928},
#  {'category': u'Literature',
#   'link': '/wiki/Sigrid_Undset',
#   'name': u'Sigrid Undset',
#   'year': 1928},
#  {'category': u'Physics',
#   'link': '/wiki/Louis_de_Broglie',
#   'name': u'Louis de Broglie',
#   'year': 1929},
#  {'category': u'Chemistry',
#   'link': '/wiki/Arthur_Harden',
#   'name': u'Arthur Harden',
#   'year': 1929},
#  {'category': u'Chemistry',
#   'link': '/wiki/Hans_von_Euler-Chelpin',
#   'name': u'Hans von Euler-Chelpin',
#   'year': 1929},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Christiaan_Eijkman',
#   'name': u'Christiaan Eijkman',
#   'year': 1929},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Frederick_Gowland_Hopkins',
#   'name': u'Frederick Gowland Hopkins',
#   'year': 1929},
#  {'category': u'Literature',
#   'link': '/wiki/Thomas_Mann',
#   'name': u'Thomas Mann',
#   'year': 1929},
#  {'category': u'Peace',
#   'link': '/wiki/Frank_B._Kellogg',
#   'name': u'Frank B. Kellogg',
#   'year': 1929},
#  {'category': u'Physics',
#   'link': '/wiki/C._V._Raman',
#   'name': u'C. V. Raman',
#   'year': 1930},
#  {'category': u'Chemistry',
#   'link': '/wiki/Hans_Fischer',
#   'name': u'Hans Fischer',
#   'year': 1930},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Karl_Landsteiner',
#   'name': u'Karl Landsteiner',
#   'year': 1930},
#  {'category': u'Literature',
#   'link': '/wiki/Sinclair_Lewis',
#   'name': u'Sinclair Lewis',
#   'year': 1930},
#  {'category': u'Peace',
#   'link': '/wiki/Nathan_S%C3%B6derblom',
#   'name': u'Nathan S\xf6derblom',
#   'year': 1930},
#  {'category': u'Chemistry',
#   'link': '/wiki/Carl_Bosch',
#   'name': u'Carl Bosch',
#   'year': 1931},
#  {'category': u'Chemistry',
#   'link': '/wiki/Friedrich_Bergius',
#   'name': u'Friedrich Bergius',
#   'year': 1931},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Otto_Heinrich_Warburg',
#   'name': u'Otto Heinrich Warburg',
#   'year': 1931},
#  {'category': u'Literature',
#   'link': '/wiki/Erik_Axel_Karlfeldt',
#   'name': u'Erik Axel Karlfeldt',
#   'year': 1931},
#  {'category': u'Peace',
#   'link': '/wiki/Jane_Addams',
#   'name': u'Jane Addams',
#   'year': 1931},
#  {'category': u'Peace',
#   'link': '/wiki/Nicholas_Murray_Butler',
#   'name': u'Nicholas Murray Butler',
#   'year': 1931},
#  {'category': u'Physics',
#   'link': '/wiki/Werner_Heisenberg',
#   'name': u'Werner Heisenberg',
#   'year': 1932},
#  {'category': u'Chemistry',
#   'link': '/wiki/Irving_Langmuir',
#   'name': u'Irving Langmuir',
#   'year': 1932},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Charles_Scott_Sherrington',
#   'name': u'Charles Scott Sherrington',
#   'year': 1932},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Edgar_Adrian,_1st_Baron_Adrian',
#   'name': u'Edgar Adrian',
#   'year': 1932},
#  {'category': u'Literature',
#   'link': '/wiki/John_Galsworthy',
#   'name': u'John Galsworthy',
#   'year': 1932},
#  {'category': u'Physics',
#   'link': '/wiki/Erwin_Schr%C3%B6dinger',
#   'name': u'Erwin Schr\xf6dinger',
#   'year': 1933},
#  {'category': u'Physics',
#   'link': '/wiki/Paul_Dirac',
#   'name': u'Paul Dirac',
#   'year': 1933},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Thomas_Hunt_Morgan',
#   'name': u'Thomas Hunt Morgan',
#   'year': 1933},
#  {'category': u'Literature',
#   'link': '/wiki/Ivan_Bunin',
#   'name': u'Ivan Bunin',
#   'year': 1933},
#  {'category': u'Peace',
#   'link': '/wiki/Norman_Angell',
#   'name': u'Norman Angell',
#   'year': 1933},
#  {'category': u'Chemistry',
#   'link': '/wiki/Harold_Urey',
#   'name': u'Harold Urey',
#   'year': 1934},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/George_Whipple',
#   'name': u'George Whipple',
#   'year': 1934},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/George_Minot',
#   'name': u'George Minot',
#   'year': 1934},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/William_P._Murphy',
#   'name': u'William P. Murphy',
#   'year': 1934},
#  {'category': u'Literature',
#   'link': '/wiki/Luigi_Pirandello',
#   'name': u'Luigi Pirandello',
#   'year': 1934},
#  {'category': u'Peace',
#   'link': '/wiki/Arthur_Henderson',
#   'name': u'Arthur Henderson',
#   'year': 1934},
#  {'category': u'Physics',
#   'link': '/wiki/James_Chadwick',
#   'name': u'James Chadwick',
#   'year': 1935},
#  {'category': u'Chemistry',
#   'link': '/wiki/Fr%C3%A9d%C3%A9ric_Joliot-Curie',
#   'name': u'Fr\xe9d\xe9ric Joliot-Curie',
#   'year': 1935},
#  {'category': u'Chemistry',
#   'link': '/wiki/Ir%C3%A8ne_Joliot-Curie',
#   'name': u'Ir\xe8ne Joliot-Curie',
#   'year': 1935},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Hans_Spemann',
#   'name': u'Hans Spemann',
#   'year': 1935},
#  {'category': u'Peace',
#   'link': '/wiki/Carl_von_Ossietzky',
#   'name': u'Carl von Ossietzky',
#   'year': 1935},
#  {'category': u'Physics',
#   'link': '/wiki/Victor_Francis_Hess',
#   'name': u'Victor Francis Hess',
#   'year': 1936},
#  {'category': u'Physics',
#   'link': '/wiki/Carl_David_Anderson',
#   'name': u'Carl David Anderson',
#   'year': 1936},
#  {'category': u'Chemistry',
#   'link': '/wiki/Peter_Debye',
#   'name': u'Peter Debye',
#   'year': 1936},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Henry_Hallett_Dale',
#   'name': u'Henry Hallett Dale',
#   'year': 1936},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Otto_Loewi',
#   'name': u'Otto Loewi',
#   'year': 1936},
#  {'category': u'Literature',
#   'link': '/wiki/Eugene_O%27Neill',
#   'name': u"Eugene O'Neill",
#   'year': 1936},
#  {'category': u'Peace',
#   'link': '/wiki/Carlos_Saavedra_Lamas',
#   'name': u'Carlos Saavedra Lamas',
#   'year': 1936},
#  {'category': u'Physics',
#   'link': '/wiki/Clinton_Davisson',
#   'name': u'Clinton Davisson',
#   'year': 1937},
#  {'category': u'Physics',
#   'link': '/wiki/George_Paget_Thomson',
#   'name': u'George Paget Thomson',
#   'year': 1937},
#  {'category': u'Chemistry',
#   'link': '/wiki/Norman_Haworth',
#   'name': u'Norman Haworth',
#   'year': 1937},
#  {'category': u'Chemistry',
#   'link': '/wiki/Paul_Karrer',
#   'name': u'Paul Karrer',
#   'year': 1937},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Albert_Szent-Gy%C3%B6rgyi',
#   'name': u'Albert Szent-Gy\xf6rgyi',
#   'year': 1937},
#  {'category': u'Literature',
#   'link': '/wiki/Roger_Martin_du_Gard',
#   'name': u'Roger Martin du Gard',
#   'year': 1937},
#  {'category': u'Peace',
#   'link': '/wiki/Robert_Cecil,_1st_Viscount_Cecil_of_Chelwood',
#   'name': u'The Viscount Cecil of Chelwood',
#   'year': 1937},
#  {'category': u'Physics',
#   'link': '/wiki/Enrico_Fermi',
#   'name': u'Enrico Fermi',
#   'year': 1938},
#  {'category': u'Chemistry',
#   'link': '/wiki/Richard_Kuhn',
#   'name': u'Richard Kuhn',
#   'year': 1938},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Corneille_Heymans',
#   'name': u'Corneille Heymans',
#   'year': 1938},
#  {'category': u'Literature',
#   'link': '/wiki/Pearl_S._Buck',
#   'name': u'Pearl S. Buck',
#   'year': 1938},
#  {'category': u'Peace',
#   'link': '/wiki/Office_international_Nansen_pour_les_r%C3%A9fugi%C3%A9s',
#   'name': u'Nansen International Office For Refugees',
#   'year': 1938},
#  {'category': u'Physics',
#   'link': '/wiki/Ernest_Lawrence',
#   'name': u'Ernest Lawrence',
#   'year': 1939},
#  {'category': u'Chemistry',
#   'link': '/wiki/Adolf_Butenandt',
#   'name': u'Adolf Butenandt',
#   'year': 1939},
#  {'category': u'Chemistry',
#   'link': '/wiki/Leopold_Ru%C5%BEi%C4%8Dka',
#   'name': u'Leopold Ru\u017ei\u010dka',
#   'year': 1939},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Gerhard_Domagk',
#   'name': u'Gerhard Domagk',
#   'year': 1939},
#  {'category': u'Literature',
#   'link': '/wiki/Frans_Eemil_Sillanp%C3%A4%C3%A4',
#   'name': u'Frans Eemil Sillanp\xe4\xe4',
#   'year': 1939},
#  {'category': u'Physics',
#   'link': '/wiki/Otto_Stern',
#   'name': u'Otto Stern',
#   'year': 1943},
#  {'category': u'Chemistry',
#   'link': '/wiki/George_de_Hevesy',
#   'name': u'George de Hevesy',
#   'year': 1943},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Henrik_Dam',
#   'name': u'Henrik Dam',
#   'year': 1943},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Edward_Adelbert_Doisy',
#   'name': u'Edward Adelbert Doisy',
#   'year': 1943},
#  {'category': u'Physics',
#   'link': '/wiki/Isidor_Isaac_Rabi',
#   'name': u'Isidor Isaac Rabi',
#   'year': 1944},
#  {'category': u'Chemistry',
#   'link': '/wiki/Otto_Hahn',
#   'name': u'Otto Hahn',
#   'year': 1944},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Joseph_Erlanger',
#   'name': u'Joseph Erlanger',
#   'year': 1944},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Herbert_Spencer_Gasser',
#   'name': u'Herbert Spencer Gasser',
#   'year': 1944},
#  {'category': u'Literature',
#   'link': '/wiki/Johannes_Vilhelm_Jensen',
#   'name': u'Johannes Vilhelm Jensen',
#   'year': 1944},
#  {'category': u'Peace',
#   'link': '/wiki/International_Committee_of_the_Red_Cross',
#   'name': u'International Committee of the Red Cross',
#   'year': 1944},
#  {'category': u'Physics',
#   'link': '/wiki/Wolfgang_Pauli',
#   'name': u'Wolfgang Pauli',
#   'year': 1945},
#  {'category': u'Chemistry',
#   'link': '/wiki/Artturi_Ilmari_Virtanen',
#   'name': u'Artturi Ilmari Virtanen',
#   'year': 1945},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Alexander_Fleming',
#   'name': u'Alexander Fleming',
#   'year': 1945},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Ernst_Boris_Chain',
#   'name': u'Ernst Boris Chain',
#   'year': 1945},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Howard_Florey',
#   'name': u'Howard Florey',
#   'year': 1945},
#  {'category': u'Literature',
#   'link': '/wiki/Gabriela_Mistral',
#   'name': u'Gabriela Mistral',
#   'year': 1945},
#  {'category': u'Peace',
#   'link': '/wiki/Cordell_Hull',
#   'name': u'Cordell Hull',
#   'year': 1945},
#  {'category': u'Physics',
#   'link': '/wiki/Percy_Williams_Bridgman',
#   'name': u'Percy Williams Bridgman',
#   'year': 1946},
#  {'category': u'Chemistry',
#   'link': '/wiki/James_B._Sumner',
#   'name': u'James B. Sumner',
#   'year': 1946},
#  {'category': u'Chemistry',
#   'link': '/wiki/John_Howard_Northrop',
#   'name': u'John Howard Northrop',
#   'year': 1946},
#  {'category': u'Chemistry',
#   'link': '/wiki/Wendell_Meredith_Stanley',
#   'name': u'Wendell Meredith Stanley',
#   'year': 1946},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Hermann_Joseph_Muller',
#   'name': u'Hermann Joseph Muller',
#   'year': 1946},
#  {'category': u'Literature',
#   'link': '/wiki/Hermann_Hesse',
#   'name': u'Hermann Hesse',
#   'year': 1946},
#  {'category': u'Peace',
#   'link': '/wiki/Emily_Greene_Balch',
#   'name': u'Emily Greene Balch',
#   'year': 1946},
#  {'category': u'Peace',
#   'link': '/wiki/John_Mott',
#   'name': u'John Mott',
#   'year': 1946},
#  {'category': u'Physics',
#   'link': '/wiki/Edward_Victor_Appleton',
#   'name': u'Edward Victor Appleton',
#   'year': 1947},
#  {'category': u'Chemistry',
#   'link': '/wiki/Robert_Robinson_(organic_chemist)',
#   'name': u'Robert Robinson',
#   'year': 1947},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Carl_Ferdinand_Cori',
#   'name': u'Carl Ferdinand Cori',
#   'year': 1947},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Gerty_Cori',
#   'name': u'Gerty Cori',
#   'year': 1947},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Bernardo_Houssay',
#   'name': u'Bernardo Houssay',
#   'year': 1947},
#  {'category': u'Literature',
#   'link': '/wiki/Andr%C3%A9_Gide',
#   'name': u'Andr\xe9 Gide',
#   'year': 1947},
#  {'category': u'Peace',
#   'link': '/wiki/Quaker_Peace_and_Social_Witness',
#   'name': u'Friends Service Council',
#   'year': 1947},
#  {'category': u'Peace',
#   'link': '/wiki/American_Friends_Service_Committee',
#   'name': u'American Friends Service Committee',
#   'year': 1947},
#  {'category': u'Physics',
#   'link': '/wiki/Patrick_Blackett,_Baron_Blackett',
#   'name': u'Patrick Blackett',
#   'year': 1948},
#  {'category': u'Chemistry',
#   'link': '/wiki/Arne_Tiselius',
#   'name': u'Arne Tiselius',
#   'year': 1948},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Paul_Hermann_M%C3%BCller',
#   'name': u'Paul Hermann M\xfcller',
#   'year': 1948},
#  {'category': u'Literature',
#   'link': '/wiki/T._S._Eliot',
#   'name': u'T. S. Eliot',
#   'year': 1948},
#  {'category': u'Physics',
#   'link': '/wiki/Hideki_Yukawa',
#   'name': u'Hideki Yukawa',
#   'year': 1949},
#  {'category': u'Chemistry',
#   'link': '/wiki/William_Giauque',
#   'name': u'William Giauque',
#   'year': 1949},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Walter_Rudolf_Hess',
#   'name': u'Walter Rudolf Hess',
#   'year': 1949},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Ant%C3%B3nio_Egas_Moniz',
#   'name': u'Ant\xf3nio Egas Moniz',
#   'year': 1949},
#  {'category': u'Literature',
#   'link': '/wiki/William_Faulkner',
#   'name': u'William Faulkner',
#   'year': 1949},
#  {'category': u'Peace',
#   'link': '/wiki/John_Boyd_Orr,_1st_Baron_Boyd-Orr',
#   'name': u'John Boyd Orr',
#   'year': 1949},
#  {'category': u'Physics',
#   'link': '/wiki/C._F._Powell',
#   'name': u'C. F. Powell',
#   'year': 1950},
#  {'category': u'Chemistry',
#   'link': '/wiki/Otto_Diels',
#   'name': u'Otto Diels',
#   'year': 1950},
#  {'category': u'Chemistry',
#   'link': '/wiki/Kurt_Alder',
#   'name': u'Kurt Alder',
#   'year': 1950},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Philip_Showalter_Hench',
#   'name': u'Philip Showalter Hench',
#   'year': 1950},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Edward_Calvin_Kendall',
#   'name': u'Edward Calvin Kendall',
#   'year': 1950},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Tadeus_Reichstein',
#   'name': u'Tadeus Reichstein',
#   'year': 1950},
#  {'category': u'Literature',
#   'link': '/wiki/Bertrand_Russell',
#   'name': u'Bertrand Russell',
#   'year': 1950},
#  {'category': u'Peace',
#   'link': '/wiki/Ralph_Bunche',
#   'name': u'Ralph Bunche',
#   'year': 1950},
#  {'category': u'Physics',
#   'link': '/wiki/John_Cockcroft',
#   'name': u'John Cockcroft',
#   'year': 1951},
#  {'category': u'Physics',
#   'link': '/wiki/Ernest_Walton',
#   'name': u'Ernest Walton',
#   'year': 1951},
#  {'category': u'Chemistry',
#   'link': '/wiki/Edwin_McMillan',
#   'name': u'Edwin McMillan',
#   'year': 1951},
#  {'category': u'Chemistry',
#   'link': '/wiki/Glenn_T._Seaborg',
#   'name': u'Glenn T. Seaborg',
#   'year': 1951},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Max_Theiler',
#   'name': u'Max Theiler',
#   'year': 1951},
#  {'category': u'Literature',
#   'link': '/wiki/P%C3%A4r_Lagerkvist',
#   'name': u'P\xe4r Lagerkvist',
#   'year': 1951},
#  {'category': u'Peace',
#   'link': '/wiki/L%C3%A9on_Jouhaux',
#   'name': u'L\xe9on Jouhaux',
#   'year': 1951},
#  {'category': u'Physics',
#   'link': '/wiki/Felix_Bloch',
#   'name': u'Felix Bloch',
#   'year': 1952},
#  {'category': u'Physics',
#   'link': '/wiki/Edward_Mills_Purcell',
#   'name': u'Edward Mills Purcell',
#   'year': 1952},
#  {'category': u'Chemistry',
#   'link': '/wiki/Archer_John_Porter_Martin',
#   'name': u'Archer John Porter Martin',
#   'year': 1952},
#  {'category': u'Chemistry',
#   'link': '/wiki/Richard_Laurence_Millington_Synge',
#   'name': u'Richard Laurence Millington Synge',
#   'year': 1952},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Selman_Waksman',
#   'name': u'Selman Waksman',
#   'year': 1952},
#  {'category': u'Literature',
#   'link': '/wiki/Fran%C3%A7ois_Mauriac',
#   'name': u'Fran\xe7ois Mauriac',
#   'year': 1952},
#  {'category': u'Peace',
#   'link': '/wiki/Albert_Schweitzer',
#   'name': u'Albert Schweitzer',
#   'year': 1952},
#  {'category': u'Physics',
#   'link': '/wiki/Frits_Zernike',
#   'name': u'Frits Zernike',
#   'year': 1953},
#  {'category': u'Chemistry',
#   'link': '/wiki/Hermann_Staudinger',
#   'name': u'Hermann Staudinger',
#   'year': 1953},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Hans_Adolf_Krebs',
#   'name': u'Hans Adolf Krebs',
#   'year': 1953},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Fritz_Albert_Lipmann',
#   'name': u'Fritz Albert Lipmann',
#   'year': 1953},
#  {'category': u'Literature',
#   'link': '/wiki/Winston_Churchill',
#   'name': u'Winston Churchill',
#   'year': 1953},
#  {'category': u'Peace',
#   'link': '/wiki/George_Marshall',
#   'name': u'George Marshall',
#   'year': 1953},
#  {'category': u'Physics',
#   'link': '/wiki/Max_Born',
#   'name': u'Max Born',
#   'year': 1954},
#  {'category': u'Physics',
#   'link': '/wiki/Walther_Bothe',
#   'name': u'Walther Bothe',
#   'year': 1954},
#  {'category': u'Chemistry',
#   'link': '/wiki/Linus_Pauling',
#   'name': u'Linus Pauling',
#   'year': 1954},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/John_Franklin_Enders',
#   'name': u'John Franklin Enders',
#   'year': 1954},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Frederick_Chapman_Robbins',
#   'name': u'Frederick Chapman Robbins',
#   'year': 1954},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Thomas_Huckle_Weller',
#   'name': u'Thomas Huckle Weller',
#   'year': 1954},
#  {'category': u'Literature',
#   'link': '/wiki/Ernest_Hemingway',
#   'name': u'Ernest Hemingway',
#   'year': 1954},
#  {'category': u'Peace',
#   'link': '/wiki/United_Nations_High_Commissioner_for_Refugees',
#   'name': u'United Nations High Commissioner for Refugees',
#   'year': 1954},
#  {'category': u'Physics',
#   'link': '/wiki/Willis_Lamb',
#   'name': u'Willis Lamb',
#   'year': 1955},
#  {'category': u'Physics',
#   'link': '/wiki/Polykarp_Kusch',
#   'name': u'Polykarp Kusch',
#   'year': 1955},
#  {'category': u'Chemistry',
#   'link': '/wiki/Vincent_du_Vigneaud',
#   'name': u'Vincent du Vigneaud',
#   'year': 1955},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Hugo_Theorell',
#   'name': u'Hugo Theorell',
#   'year': 1955},
#  {'category': u'Literature',
#   'link': '/wiki/Halld%C3%B3r_Laxness',
#   'name': u'Halld\xf3r Laxness',
#   'year': 1955},
#  {'category': u'Physics',
#   'link': '/wiki/John_Bardeen',
#   'name': u'John Bardeen',
#   'year': 1956},
#  {'category': u'Physics',
#   'link': '/wiki/Walter_Houser_Brattain',
#   'name': u'Walter Houser Brattain',
#   'year': 1956},
#  {'category': u'Physics',
#   'link': '/wiki/William_Shockley',
#   'name': u'William Shockley',
#   'year': 1956},
#  {'category': u'Chemistry',
#   'link': '/wiki/Cyril_Norman_Hinshelwood',
#   'name': u'Cyril Norman Hinshelwood',
#   'year': 1956},
#  {'category': u'Chemistry',
#   'link': '/wiki/Nikolay_Semyonov',
#   'name': u'Nikolay Semyonov',
#   'year': 1956},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Andr%C3%A9_Fr%C3%A9d%C3%A9ric_Cournand',
#   'name': u'Andr\xe9 Fr\xe9d\xe9ric Cournand',
#   'year': 1956},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Werner_Forssmann',
#   'name': u'Werner Forssmann',
#   'year': 1956},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Dickinson_W._Richards',
#   'name': u'Dickinson W. Richards',
#   'year': 1956},
#  {'category': u'Literature',
#   'link': '/wiki/Juan_Ram%C3%B3n_Jim%C3%A9nez',
#   'name': u'Juan Ram\xf3n Jim\xe9nez',
#   'year': 1956},
#  {'category': u'Physics',
#   'link': '/wiki/Chen_Ning_Yang',
#   'name': u'Chen Ning Yang',
#   'year': 1957},
#  {'category': u'Physics',
#   'link': '/wiki/Tsung-Dao_Lee',
#   'name': u'Tsung-Dao Lee',
#   'year': 1957},
#  {'category': u'Chemistry',
#   'link': '/wiki/Alexander_R._Todd,_Baron_Todd',
#   'name': u'The Lord Todd',
#   'year': 1957},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Daniel_Bovet',
#   'name': u'Daniel Bovet',
#   'year': 1957},
#  {'category': u'Literature',
#   'link': '/wiki/Albert_Camus',
#   'name': u'Albert Camus',
#   'year': 1957},
#  {'category': u'Peace',
#   'link': '/wiki/Lester_B._Pearson',
#   'name': u'Lester B. Pearson',
#   'year': 1957},
#  {'category': u'Physics',
#   'link': '/wiki/Pavel_Cherenkov',
#   'name': u'Pavel Cherenkov',
#   'year': 1958},
#  {'category': u'Physics',
#   'link': '/wiki/Ilya_Frank',
#   'name': u'Ilya Frank',
#   'year': 1958},
#  {'category': u'Physics',
#   'link': '/wiki/Igor_Tamm',
#   'name': u'Igor Tamm',
#   'year': 1958},
#  {'category': u'Chemistry',
#   'link': '/wiki/Frederick_Sanger',
#   'name': u'Frederick Sanger',
#   'year': 1958},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/George_Wells_Beadle',
#   'name': u'George Wells Beadle',
#   'year': 1958},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Edward_Lawrie_Tatum',
#   'name': u'Edward Lawrie Tatum',
#   'year': 1958},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Joshua_Lederberg',
#   'name': u'Joshua Lederberg',
#   'year': 1958},
#  {'category': u'Literature',
#   'link': '/wiki/Boris_Pasternak',
#   'name': u'Boris Pasternak',
#   'year': 1958},
#  {'category': u'Peace',
#   'link': '/wiki/Dominique_Pire',
#   'name': u'Dominique Pire',
#   'year': 1958},
#  {'category': u'Physics',
#   'link': '/wiki/Emilio_G._Segr%C3%A8',
#   'name': u'Emilio G. Segr\xe8',
#   'year': 1959},
#  {'category': u'Physics',
#   'link': '/wiki/Owen_Chamberlain',
#   'name': u'Owen Chamberlain',
#   'year': 1959},
#  {'category': u'Chemistry',
#   'link': '/wiki/Jaroslav_Heyrovsk%C3%BD',
#   'name': u'Jaroslav Heyrovsk\xfd',
#   'year': 1959},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Arthur_Kornberg',
#   'name': u'Arthur Kornberg',
#   'year': 1959},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Severo_Ochoa',
#   'name': u'Severo Ochoa',
#   'year': 1959},
#  {'category': u'Literature',
#   'link': '/wiki/Salvatore_Quasimodo',
#   'name': u'Salvatore Quasimodo',
#   'year': 1959},
#  {'category': u'Peace',
#   'link': '/wiki/Philip_Noel-Baker,_Baron_Noel-Baker',
#   'name': u'Philip Noel-Baker',
#   'year': 1959},
#  {'category': u'Physics',
#   'link': '/wiki/Donald_A._Glaser',
#   'name': u'Donald A. Glaser',
#   'year': 1960},
#  {'category': u'Chemistry',
#   'link': '/wiki/Willard_Libby',
#   'name': u'Willard Libby',
#   'year': 1960},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Frank_Macfarlane_Burnet',
#   'name': u'Frank Macfarlane Burnet',
#   'year': 1960},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Peter_Medawar',
#   'name': u'Peter Medawar',
#   'year': 1960},
#  {'category': u'Literature',
#   'link': '/wiki/Saint-John_Perse',
#   'name': u'Saint-John Perse',
#   'year': 1960},
#  {'category': u'Peace',
#   'link': '/wiki/Albert_Lutuli',
#   'name': u'Albert Lutuli',
#   'year': 1960},
#  {'category': u'Physics',
#   'link': '/wiki/Robert_Hofstadter',
#   'name': u'Robert Hofstadter',
#   'year': 1961},
#  {'category': u'Physics',
#   'link': '/wiki/Rudolf_M%C3%B6ssbauer',
#   'name': u'Rudolf M\xf6ssbauer',
#   'year': 1961},
#  {'category': u'Chemistry',
#   'link': '/wiki/Melvin_Calvin',
#   'name': u'Melvin Calvin',
#   'year': 1961},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Georg_von_B%C3%A9k%C3%A9sy',
#   'name': u'Georg von B\xe9k\xe9sy',
#   'year': 1961},
#  {'category': u'Literature',
#   'link': '/wiki/Ivo_Andri%C4%87',
#   'name': u'Ivo Andri\u0107',
#   'year': 1961},
#  {'category': u'Peace',
#   'link': '/wiki/Dag_Hammarskj%C3%B6ld',
#   'name': u'Dag Hammarskj\xf6ld',
#   'year': 1961},
#  {'category': u'Physics',
#   'link': '/wiki/Lev_Landau',
#   'name': u'Lev Landau',
#   'year': 1962},
#  {'category': u'Chemistry',
#   'link': '/wiki/Max_Perutz',
#   'name': u'Max Perutz',
#   'year': 1962},
#  {'category': u'Chemistry',
#   'link': '/wiki/John_Kendrew',
#   'name': u'John Kendrew',
#   'year': 1962},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Francis_Crick',
#   'name': u'Francis Crick',
#   'year': 1962},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/James_D._Watson',
#   'name': u'James D. Watson',
#   'year': 1962},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Maurice_Wilkins',
#   'name': u'Maurice Wilkins',
#   'year': 1962},
#  {'category': u'Literature',
#   'link': '/wiki/John_Steinbeck',
#   'name': u'John Steinbeck',
#   'year': 1962},
#  {'category': u'Peace',
#   'link': '/wiki/Linus_Pauling',
#   'name': u'Linus Pauling',
#   'year': 1962},
#  {'category': u'Physics',
#   'link': '/wiki/Eugene_Wigner',
#   'name': u'Eugene Wigner',
#   'year': 1963},
#  {'category': u'Physics',
#   'link': '/wiki/Maria_Goeppert-Mayer',
#   'name': u'Maria Goeppert-Mayer',
#   'year': 1963},
#  {'category': u'Physics',
#   'link': '/wiki/J._Hans_D._Jensen',
#   'name': u'J. Hans D. Jensen',
#   'year': 1963},
#  {'category': u'Chemistry',
#   'link': '/wiki/Karl_Ziegler',
#   'name': u'Karl Ziegler',
#   'year': 1963},
#  {'category': u'Chemistry',
#   'link': '/wiki/Giulio_Natta',
#   'name': u'Giulio Natta',
#   'year': 1963},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/John_Eccles_(neurophysiologist)',
#   'name': u'John Eccles',
#   'year': 1963},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Alan_Lloyd_Hodgkin',
#   'name': u'Alan Lloyd Hodgkin',
#   'year': 1963},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Andrew_Huxley',
#   'name': u'Andrew Huxley',
#   'year': 1963},
#  {'category': u'Literature',
#   'link': '/wiki/Giorgos_Seferis',
#   'name': u'Giorgos Seferis',
#   'year': 1963},
#  {'category': u'Peace',
#   'link': '/wiki/International_Committee_of_the_Red_Cross',
#   'name': u'International Committee of the Red Cross',
#   'year': 1963},
#  {'category': u'Peace',
#   'link': '/wiki/International_Federation_of_Red_Cross_and_Red_Crescent_Societies',
#   'name': u'League of Red Cross societies',
#   'year': 1963},
#  {'category': u'Physics',
#   'link': '/wiki/Charles_Hard_Townes',
#   'name': u'Charles Hard Townes',
#   'year': 1964},
#  {'category': u'Physics',
#   'link': '/wiki/Nikolay_Basov',
#   'name': u'Nikolay Basov',
#   'year': 1964},
#  {'category': u'Physics',
#   'link': '/wiki/Alexander_Prokhorov',
#   'name': u'Alexander Prokhorov',
#   'year': 1964},
#  {'category': u'Chemistry',
#   'link': '/wiki/Dorothy_Hodgkin',
#   'name': u'Dorothy Hodgkin',
#   'year': 1964},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Konrad_Emil_Bloch',
#   'name': u'Konrad Emil Bloch',
#   'year': 1964},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Feodor_Felix_Konrad_Lynen',
#   'name': u'Feodor Felix Konrad Lynen',
#   'year': 1964},
#  {'category': u'Literature',
#   'link': '/wiki/Jean-Paul_Sartre',
#   'name': u'Jean-Paul Sartre',
#   'year': 1964},
#  {'category': u'Peace',
#   'link': '/wiki/Martin_Luther_King,_Jr.',
#   'name': u'Martin Luther King, Jr.',
#   'year': 1964},
#  {'category': u'Physics',
#   'link': '/wiki/Sin-Itiro_Tomonaga',
#   'name': u'Sin-Itiro Tomonaga',
#   'year': 1965},
#  {'category': u'Physics',
#   'link': '/wiki/Julian_Schwinger',
#   'name': u'Julian Schwinger',
#   'year': 1965},
#  {'category': u'Physics',
#   'link': '/wiki/Richard_Feynman',
#   'name': u'Richard Feynman',
#   'year': 1965},
#  {'category': u'Chemistry',
#   'link': '/wiki/Robert_Burns_Woodward',
#   'name': u'Robert Burns Woodward',
#   'year': 1965},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Fran%C3%A7ois_Jacob',
#   'name': u'Fran\xe7ois Jacob',
#   'year': 1965},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Andr%C3%A9_Michel_Lwoff',
#   'name': u'Andr\xe9 Michel Lwoff',
#   'year': 1965},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Jacques_Monod',
#   'name': u'Jacques Monod',
#   'year': 1965},
#  {'category': u'Literature',
#   'link': '/wiki/Mikhail_Sholokhov',
#   'name': u'Mikhail Sholokhov',
#   'year': 1965},
#  {'category': u'Peace',
#   'link': '/wiki/UNICEF',
#   'name': u"United Nations International Children's Emergency Fund (UNICEF)",
#   'year': 1965},
#  {'category': u'Physics',
#   'link': '/wiki/Alfred_Kastler',
#   'name': u'Alfred Kastler',
#   'year': 1966},
#  {'category': u'Chemistry',
#   'link': '/wiki/Robert_S._Mulliken',
#   'name': u'Robert S. Mulliken',
#   'year': 1966},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Francis_Peyton_Rous',
#   'name': u'Francis Peyton Rous',
#   'year': 1966},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Charles_Brenton_Huggins',
#   'name': u'Charles Brenton Huggins',
#   'year': 1966},
#  {'category': u'Literature',
#   'link': '/wiki/Shmuel_Yosef_Agnon',
#   'name': u'Shmuel Yosef Agnon',
#   'year': 1966},
#  {'category': u'Literature',
#   'link': '/wiki/Nelly_Sachs',
#   'name': u'Nelly Sachs',
#   'year': 1966},
#  {'category': u'Physics',
#   'link': '/wiki/Hans_Bethe',
#   'name': u'Hans Bethe',
#   'year': 1967},
#  {'category': u'Chemistry',
#   'link': '/wiki/Manfred_Eigen',
#   'name': u'Manfred Eigen',
#   'year': 1967},
#  {'category': u'Chemistry',
#   'link': '/wiki/Ronald_George_Wreyford_Norrish',
#   'name': u'Ronald George Wreyford Norrish',
#   'year': 1967},
#  {'category': u'Chemistry',
#   'link': '/wiki/George_Porter',
#   'name': u'George Porter',
#   'year': 1967},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Ragnar_Granit',
#   'name': u'Ragnar Granit',
#   'year': 1967},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Haldan_Keffer_Hartline',
#   'name': u'Haldan Keffer Hartline',
#   'year': 1967},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/George_Wald',
#   'name': u'George Wald',
#   'year': 1967},
#  {'category': u'Literature',
#   'link': '/wiki/Miguel_%C3%81ngel_Asturias',
#   'name': u'Miguel \xc1ngel Asturias',
#   'year': 1967},
#  {'category': u'Physics',
#   'link': '/wiki/Luis_Walter_Alvarez',
#   'name': u'Luis Walter Alvarez',
#   'year': 1968},
#  {'category': u'Chemistry',
#   'link': '/wiki/Lars_Onsager',
#   'name': u'Lars Onsager',
#   'year': 1968},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Robert_W._Holley',
#   'name': u'Robert W. Holley',
#   'year': 1968},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Har_Gobind_Khorana',
#   'name': u'Har Gobind Khorana',
#   'year': 1968},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Marshall_Warren_Nirenberg',
#   'name': u'Marshall Warren Nirenberg',
#   'year': 1968},
#  {'category': u'Literature',
#   'link': '/wiki/Yasunari_Kawabata',
#   'name': u'Yasunari Kawabata',
#   'year': 1968},
#  {'category': u'Peace',
#   'link': '/wiki/Ren%C3%A9_Cassin',
#   'name': u'Ren\xe9 Cassin',
#   'year': 1968},
#  {'category': u'Physics',
#   'link': '/wiki/Murray_Gell-Mann',
#   'name': u'Murray Gell-Mann',
#   'year': 1969},
#  {'category': u'Chemistry',
#   'link': '/wiki/Derek_Barton',
#   'name': u'Derek Barton',
#   'year': 1969},
#  {'category': u'Chemistry',
#   'link': '/wiki/Odd_Hassel',
#   'name': u'Odd Hassel',
#   'year': 1969},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Max_Delbr%C3%BCck',
#   'name': u'Max Delbr\xfcck',
#   'year': 1969},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Alfred_Hershey',
#   'name': u'Alfred Hershey',
#   'year': 1969},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Salvador_Luria',
#   'name': u'Salvador Luria',
#   'year': 1969},
#  {'category': u'Literature',
#   'link': '/wiki/Samuel_Beckett',
#   'name': u'Samuel Beckett',
#   'year': 1969},
#  {'category': u'Peace',
#   'link': '/wiki/International_Labour_Organization',
#   'name': u'International Labour Organization',
#   'year': 1969},
#  {'category': u'Economics',
#   'link': '/wiki/Ragnar_Frisch',
#   'name': u'Ragnar Frisch',
#   'year': 1969},
#  {'category': u'Economics',
#   'link': '/wiki/Jan_Tinbergen',
#   'name': u'Jan Tinbergen',
#   'year': 1969},
#  {'category': u'Physics',
#   'link': '/wiki/Hannes_Alfv%C3%A9n',
#   'name': u'Hannes Alfv\xe9n',
#   'year': 1970},
#  {'category': u'Physics',
#   'link': '/wiki/Louis_N%C3%A9el',
#   'name': u'Louis N\xe9el',
#   'year': 1970},
#  {'category': u'Chemistry',
#   'link': '/wiki/Luis_Federico_Leloir',
#   'name': u'Luis Federico Leloir',
#   'year': 1970},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Julius_Axelrod',
#   'name': u'Julius Axelrod',
#   'year': 1970},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Ulf_von_Euler',
#   'name': u'Ulf von Euler',
#   'year': 1970},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Bernard_Katz',
#   'name': u'Bernard Katz',
#   'year': 1970},
#  {'category': u'Literature',
#   'link': '/wiki/Aleksandr_Solzhenitsyn',
#   'name': u'Aleksandr Solzhenitsyn',
#   'year': 1970},
#  {'category': u'Peace',
#   'link': '/wiki/Norman_Borlaug',
#   'name': u'Norman Borlaug',
#   'year': 1970},
#  {'category': u'Economics',
# ...
#  {'category': u'Economics',
#   'link': '/wiki/Thomas_Schelling',
#   'name': u'Thomas Schelling',
#   'year': 2005},
#  {'category': u'Physics',
#   'link': '/wiki/John_C._Mather',
#   'name': u'John C. Mather',
#   'year': 2006},
#  {'category': u'Physics',
#   'link': '/wiki/George_Smoot',
#   'name': u'George Smoot',
#   'year': 2006},
#  {'category': u'Chemistry',
#   'link': '/wiki/Roger_D._Kornberg',
#   'name': u'Roger D. Kornberg',
#   'year': 2006},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Andrew_Fire',
#   'name': u'Andrew Fire',
#   'year': 2006},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Craig_Mello',
#   'name': u'Craig Mello',
#   'year': 2006},
#  {'category': u'Literature',
#   'link': '/wiki/Orhan_Pamuk',
#   'name': u'Orhan Pamuk',
#   'year': 2006},
#  {'category': u'Peace',
#   'link': '/wiki/Muhammad_Yunus',
#   'name': u'Muhammad Yunus',
#   'year': 2006},
#  {'category': u'Peace',
#   'link': '/wiki/Grameen_Bank',
#   'name': u'Grameen Bank',
#   'year': 2006},
#  {'category': u'Economics',
#   'link': '/wiki/Edmund_Phelps',
#   'name': u'Edmund Phelps',
#   'year': 2006},
#  {'category': u'Physics',
#   'link': '/wiki/Albert_Fert',
#   'name': u'Albert Fert',
#   'year': 2007},
#  {'category': u'Physics',
#   'link': '/wiki/Peter_Gr%C3%BCnberg',
#   'name': u'Peter Gr\xfcnberg',
#   'year': 2007},
#  {'category': u'Chemistry',
#   'link': '/wiki/Gerhard_Ertl',
#   'name': u'Gerhard Ertl',
#   'year': 2007},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Mario_Capecchi',
#   'name': u'Mario Capecchi',
#   'year': 2007},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Martin_Evans',
#   'name': u'Martin Evans',
#   'year': 2007},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Oliver_Smithies',
#   'name': u'Oliver Smithies',
#   'year': 2007},
#  {'category': u'Literature',
#   'link': '/wiki/Doris_Lessing',
#   'name': u'Doris Lessing',
#   'year': 2007},
#  {'category': u'Peace',
#   'link': '/wiki/Intergovernmental_Panel_on_Climate_Change',
#   'name': u'Intergovernmental Panel on Climate Change',
#   'year': 2007},
#  {'category': u'Peace',
#   'link': '/wiki/Al_Gore',
#   'name': u'Al Gore',
#   'year': 2007},
#  {'category': u'Economics',
#   'link': '/wiki/Leonid_Hurwicz',
#   'name': u'Leonid Hurwicz',
#   'year': 2007},
#  {'category': u'Economics',
#   'link': '/wiki/Eric_Maskin',
#   'name': u'Eric Maskin',
#   'year': 2007},
#  {'category': u'Economics',
#   'link': '/wiki/Roger_Myerson',
#   'name': u'Roger Myerson',
#   'year': 2007},
#  {'category': u'Physics',
#   'link': '/wiki/Yoichiro_Nambu',
#   'name': u'Yoichiro Nambu',
#   'year': 2008},
#  {'category': u'Physics',
#   'link': '/wiki/Makoto_Kobayashi_(physicist)',
#   'name': u'Makoto Kobayashi',
#   'year': 2008},
#  {'category': u'Physics',
#   'link': '/wiki/Toshihide_Maskawa',
#   'name': u'Toshihide Maskawa',
#   'year': 2008},
#  {'category': u'Chemistry',
#   'link': '/wiki/Osamu_Shimomura',
#   'name': u'Osamu Shimomura',
#   'year': 2008},
#  {'category': u'Chemistry',
#   'link': '/wiki/Martin_Chalfie',
#   'name': u'Martin Chalfie',
#   'year': 2008},
#  {'category': u'Chemistry',
#   'link': '/wiki/Roger_Y._Tsien',
#   'name': u'Roger Y. Tsien',
#   'year': 2008},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Harald_zur_Hausen',
#   'name': u'Harald zur Hausen',
#   'year': 2008},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Fran%C3%A7oise_Barr%C3%A9-Sinoussi',
#   'name': u'Fran\xe7oise Barr\xe9-Sinoussi',
#   'year': 2008},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Luc_Montagnier',
#   'name': u'Luc Montagnier',
#   'year': 2008},
#  {'category': u'Literature',
#   'link': '/wiki/J._M._G._Le_Cl%C3%A9zio',
#   'name': u'J. M. G. Le Cl\xe9zio',
#   'year': 2008},
#  {'category': u'Peace',
#   'link': '/wiki/Martti_Ahtisaari',
#   'name': u'Martti Ahtisaari',
#   'year': 2008},
#  {'category': u'Economics',
#   'link': '/wiki/Paul_Krugman',
#   'name': u'Paul Krugman',
#   'year': 2008},
#  {'category': u'Physics',
#   'link': '/wiki/Charles_K._Kao',
#   'name': u'Charles K. Kao',
#   'year': 2009},
#  {'category': u'Physics',
#   'link': '/wiki/Willard_Boyle',
#   'name': u'Willard S. Boyle',
#   'year': 2009},
#  {'category': u'Physics',
#   'link': '/wiki/George_E._Smith',
#   'name': u'George E. Smith',
#   'year': 2009},
#  {'category': u'Chemistry',
#   'link': '/wiki/Venkatraman_Ramakrishnan',
#   'name': u'Venkatraman Ramakrishnan',
#   'year': 2009},
#  {'category': u'Chemistry',
#   'link': '/wiki/Thomas_A._Steitz',
#   'name': u'Thomas A. Steitz',
#   'year': 2009},
#  {'category': u'Chemistry',
#   'link': '/wiki/Ada_Yonath',
#   'name': u'Ada Yonath',
#   'year': 2009},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Elizabeth_Blackburn',
#   'name': u'Elizabeth Blackburn',
#   'year': 2009},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Carol_W._Greider',
#   'name': u'Carol W. Greider',
#   'year': 2009},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Jack_W._Szostak',
#   'name': u'Jack W. Szostak',
#   'year': 2009},
#  {'category': u'Literature',
#   'link': '/wiki/Herta_M%C3%BCller',
#   'name': u'Herta M\xfcller',
#   'year': 2009},
#  {'category': u'Peace',
#   'link': '/wiki/Barack_Obama',
#   'name': u'Barack  Obama',
#   'year': 2009},
#  {'category': u'Economics',
#   'link': '/wiki/Elinor_Ostrom',
#   'name': u'Elinor Ostrom',
#   'year': 2009},
#  {'category': u'Economics',
#   'link': '/wiki/Oliver_E._Williamson',
#   'name': u'Oliver E. Williamson',
#   'year': 2009},
#  {'category': u'Physics',
#   'link': '/wiki/Andre_Geim',
#   'name': u'Andre Geim',
#   'year': 2010},
#  {'category': u'Physics',
#   'link': '/wiki/Konstantin_Novoselov',
#   'name': u'Konstantin Novoselov',
#   'year': 2010},
#  {'category': u'Chemistry',
#   'link': '/wiki/Richard_F._Heck',
#   'name': u'Richard F. Heck',
#   'year': 2010},
#  {'category': u'Chemistry',
#   'link': '/wiki/Ei-ichi_Negishi',
#   'name': u'Ei-ichi Negishi',
#   'year': 2010},
#  {'category': u'Chemistry',
#   'link': '/wiki/Akira_Suzuki_(chemist)',
#   'name': u'Akira Suzuki',
#   'year': 2010},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Robert_G._Edwards',
#   'name': u'Robert G. Edwards',
#   'year': 2010},
#  {'category': u'Literature',
#   'link': '/wiki/Mario_Vargas_Llosa',
#   'name': u'Mario Vargas Llosa',
#   'year': 2010},
#  {'category': u'Peace',
#   'link': '/wiki/Liu_Xiaobo',
#   'name': u'Liu Xiaobo',
#   'year': 2010},
#  {'category': u'Economics',
#   'link': '/wiki/Peter_Diamond',
#   'name': u'Peter A. Diamond',
#   'year': 2010},
#  {'category': u'Economics',
#   'link': '/wiki/Dale_T._Mortensen',
#   'name': u'Dale T.  Mortensen',
#   'year': 2010},
#  {'category': u'Economics',
#   'link': '/wiki/Christopher_A._Pissarides',
#   'name': u'Christopher A.  Pissarides',
#   'year': 2010},
#  {'category': u'Physics',
#   'link': '/wiki/Saul_Perlmutter',
#   'name': u'Saul Perlmutter',
#   'year': 2011},
#  {'category': u'Physics',
#   'link': '/wiki/Adam_Riess',
#   'name': u'Adam G. Riess',
#   'year': 2011},
#  {'category': u'Physics',
#   'link': '/wiki/Brian_Schmidt',
#   'name': u'Brian Schmidt',
#   'year': 2011},
#  {'category': u'Chemistry',
#   'link': '/wiki/Dan_Shechtman',
#   'name': u'Dan Shechtman',
#   'year': 2011},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Bruce_Beutler',
#   'name': u'Bruce Beutler',
#   'year': 2011},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Jules_A._Hoffmann',
#   'name': u'Jules A. Hoffmann',
#   'year': 2011},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Ralph_M._Steinman',
#   'name': u'Ralph M.  Steinman',
#   'year': 2011},
#  {'category': u'Literature',
#   'link': '/wiki/Tomas_Transtr%C3%B6mer',
#   'name': u'Tomas Transtr\xf6mer',
#   'year': 2011},
#  {'category': u'Peace',
#   'link': '/wiki/Ellen_Johnson_Sirleaf',
#   'name': u'Ellen Johnson Sirleaf',
#   'year': 2011},
#  {'category': u'Peace',
#   'link': '/wiki/Leymah_Gbowee',
#   'name': u'Leymah Gbowee',
#   'year': 2011},
#  {'category': u'Peace',
#   'link': '/wiki/Tawakel_Karman',
#   'name': u'Tawakel Karman',
#   'year': 2011},
#  {'category': u'Economics',
#   'link': '/wiki/Thomas_J._Sargent',
#   'name': u'Thomas J. Sargent',
#   'year': 2011},
#  {'category': u'Economics',
#   'link': '/wiki/Christopher_A._Sims',
#   'name': u'Christopher A. Sims',
#   'year': 2011},
#  {'category': u'Physics',
#   'link': '/wiki/Serge_Haroche',
#   'name': u'Serge Haroche',
#   'year': 2012},
#  {'category': u'Physics',
#   'link': '/wiki/David_J._Wineland',
#   'name': u'David  J. Wineland',
#   'year': 2012},
#  {'category': u'Chemistry',
#   'link': '/wiki/Brian_Kobilka',
#   'name': u'Brian K. Kobilka',
#   'year': 2012},
#  {'category': u'Chemistry',
#   'link': '/wiki/Robert_Lefkowitz',
#   'name': u'Robert J. Lefkowitz',
#   'year': 2012},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/John_Gurdon',
#   'name': u'John B. Gurdon',
#   'year': 2012},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Shinya_Yamanaka',
#   'name': u' Shinya Yamanaka',
#   'year': 2012},
#  {'category': u'Literature',
#   'link': '/wiki/Mo_Yan',
#   'name': u'Mo Yan',
#   'year': 2012},
#  {'category': u'Peace',
#   'link': '/wiki/European_Union',
#   'name': u'European Union',
#   'year': 2012},
#  {'category': u'Economics',
#   'link': '/wiki/Alvin_E._Roth',
#   'name': u'Alvin E. Roth',
#   'year': 2012},
#  {'category': u'Economics',
#   'link': '/wiki/Lloyd_Shapley',
#   'name': u'Lloyd S. Shapley',
#   'year': 2012},
#  {'category': u'Physics',
#   'link': '/wiki/Fran%C3%A7ois_Englert',
#   'name': u'Fran\xe7ois Englert',
#   'year': 2013},
#  {'category': u'Physics',
#   'link': '/wiki/Peter_Higgs',
#   'name': u'Peter W. Higgs',
#   'year': 2013},
#  {'category': u'Chemistry',
#   'link': '/wiki/Martin_Karplus',
#   'name': u'Martin Karplus',
#   'year': 2013},
#  {'category': u'Chemistry',
#   'link': '/wiki/Michael_Levitt',
#   'name': u'Michael Levitt',
#   'year': 2013},
#  {'category': u'Chemistry',
#   'link': '/wiki/Arieh_Warshel',
#   'name': u'Arieh Warshel',
#   'year': 2013},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/James_Rothman',
#   'name': u'James E. Rothman',
#   'year': 2013},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Randy_W._Schekman',
#   'name': u'Randy W. Schekman',
#   'year': 2013},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Thomas_C._S%C3%BCdhof',
#   'name': u'Thomas C. S\xfcdhof',
#   'year': 2013},
#  {'category': u'Literature',
#   'link': '/wiki/Alice_Munro',
#   'name': u'Alice Munro',
#   'year': 2013},
#  {'category': u'Peace',
#   'link': '/wiki/Organisation_for_the_Prohibition_of_Chemical_Weapons',
#   'name': u'Organisation for the Prohibition of Chemical Weapons',
#   'year': 2013},
#  {'category': u'Economics',
#   'link': '/wiki/Eugene_Fama',
#   'name': u'Eugene F. Fama',
#   'year': 2013},
#  {'category': u'Economics',
#   'link': '/wiki/Lars_Peter_Hansen',
#   'name': u'Lars Peter Hansen',
#   'year': 2013},
#  {'category': u'Economics',
#   'link': '/wiki/Robert_Shiller',
#   'name': u'Robert J. Shiller',
#   'year': 2013},
#  {'category': u'Physics',
#   'link': '/wiki/Isamu_Akasaki',
#   'name': u'Isamu Akasaki',
#   'year': 2014},
#  {'category': u'Physics',
#   'link': '/wiki/Hiroshi_Amano',
#   'name': u'Hiroshi Amano',
#   'year': 2014},
#  {'category': u'Physics',
#   'link': '/wiki/Shuji_Nakamura',
#   'name': u'Shuji Nakamura',
#   'year': 2014},
#  {'category': u'Chemistry',
#   'link': '/wiki/Eric_Betzig',
#   'name': u'Eric Betzig',
#   'year': 2014},
#  {'category': u'Chemistry',
#   'link': '/wiki/Stefan_Hell',
#   'name': u'Stefan Hell',
#   'year': 2014},
#  {'category': u'Chemistry',
#   'link': '/wiki/William_Moerner',
#   'name': u'William Moerner',
#   'year': 2014},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/John_O%27Keefe_(neuroscientist)',
#   'name': u"John O'Keefe",
#   'year': 2014},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/May-Britt_Moser',
#   'name': u'May-Britt Moser',
#   'year': 2014},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Edvard_Moser',
#   'name': u'Edvard  Moser',
#   'year': 2014},
#  {'category': u'Literature',
#   'link': '/wiki/Patrick_Modiano',
#   'name': u'Patrick Modiano',
#   'year': 2014},
#  {'category': u'Peace',
#   'link': '/wiki/Kailash_Satyarthi',
#   'name': u'Kailash Satyarthi',
#   'year': 2014},
#  {'category': u'Peace',
#   'link': '/wiki/Malala_Yousafzai',
#   'name': u'Malala Yousafzai',
#   'year': 2014},
#  {'category': u'Economics',
#   'link': '/wiki/Jean_Tirole',
#   'name': u'Jean Tirole',
#   'year': 2014},
#  {'category': u'Physics',
#   'link': '/wiki/Takaaki_Kajita',
#   'name': u'Takaaki Kajita',
#   'year': 2015},
#  {'category': u'Physics',
#   'link': '/wiki/Arthur_B._McDonald',
#   'name': u'Arthur B. McDonald',
#   'year': 2015},
#  {'category': u'Chemistry',
#   'link': '/wiki/Tomas_Lindahl',
#   'name': u'Tomas Lindahl',
#   'year': 2015},
#  {'category': u'Chemistry',
#   'link': '/wiki/Paul_Modrich',
#   'name': u'Paul L. Modrich',
#   'year': 2015},
#  {'category': u'Chemistry',
#   'link': '/wiki/Aziz_Sancar',
#   'name': u'Aziz Sancar',
#   'year': 2015},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/William_C._Campbell_(scientist)',
#   'name': u'William C. Campbell',
#   'year': 2015},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Satoshi_%C5%8Cmura',
#   'name': u'Satoshi \u014cmura',
#   'year': 2015},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Tu_Youyou',
#   'name': u'Tu Youyou',
#   'year': 2015},
#  {'category': u'Literature',
#   'link': '/wiki/Svetlana_Alexievich',
#   'name': u'Svetlana Alexievich',
#   'year': 2015},
#  {'category': u'Peace',
#   'link': '/wiki/Tunisian_National_Dialogue_Quartet',
#   'name': u'Tunisian National Dialogue Quartet',
#   'year': 2015},
#  {'category': u'Economics',
#   'link': '/wiki/Angus_Deaton',
#   'name': u'Angus Deaton',
#   'year': 2015},
#  {'category': u'Physics',
#   'link': '/wiki/David_J._Thouless',
#   'name': u'David J. Thouless',
#   'year': 2016},
#  {'category': u'Physics',
#   'link': '/wiki/Duncan_Haldane',
#   'name': u'Duncan Haldane',
#   'year': 2016},
#  {'category': u'Physics',
#   'link': '/wiki/John_M._Kosterlitz',
#   'name': u'John M. Kosterlitz',
#   'year': 2016},
#  {'category': u'Chemistry',
#   'link': '/wiki/Jean-Pierre_Sauvage',
#   'name': u'Jean-Pierre Sauvage',
#   'year': 2016},
#  {'category': u'Chemistry',
#   'link': '/wiki/Fraser_Stoddart',
#   'name': u'Fraser Stoddart',
#   'year': 2016},
#  {'category': u'Chemistry',
#   'link': '/wiki/Ben_Feringa',
#   'name': u'Ben Feringa',
#   'year': 2016},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Yoshinori_Ohsumi',
#   'name': u'Yoshinori Ohsumi',
#   'year': 2016},
#  {'category': u'Literature',
#   'link': '/wiki/Bob_Dylan',
#   'name': u'Bob Dylan',
#   'year': 2016},
#  {'category': u'Peace',
#   'link': '/wiki/Juan_Manuel_Santos',
#   'name': u'Juan Manuel Santos',
#   'year': 2016},
#  {'category': u'Economics',
#   'link': '/wiki/Oliver_Hart_(economist)',
#   'name': u'Oliver Hart',
#   'year': 2016},
#  {'category': u'Economics',
#   'link': '/wiki/Bengt_R._Holmstr%C3%B6m',
#   'name': u'Bengt R. Holmstr\xf6m',
#   'year': 2016},
#  {'category': u'Physics',
#   'link': '/wiki/Rainer_Weiss',
#   'name': u'Rainer Weiss',
#   'year': 2017},
#  {'category': u'Physics',
#   'link': '/wiki/Barry_Barish',
#   'name': u'Barry Barish',
#   'year': 2017},
#  {'category': u'Physics',
#   'link': '/wiki/Kip_Thorne',
#   'name': u'Kip Thorne',
#   'year': 2017},
#  {'category': u'Chemistry',
#   'link': '/wiki/Jacques_Dubochet',
#   'name': u'Jacques Dubochet',
#   'year': 2017},
#  {'category': u'Chemistry',
#   'link': '/wiki/Joachim_Frank',
#   'name': u'Joachim Frank',
#   'year': 2017},
#  {'category': u'Chemistry',
#   'link': '/wiki/Richard_Henderson_(biologist)',
#   'name': u'Richard Henderson',
#   'year': 2017},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Jeffrey_C._Hall',
#   'name': u'Jeffrey C. Hall',
#   'year': 2017},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Michael_Rosbash',
#   'name': u'Michael Rosbash',
#   'year': 2017},
#  {'category': u'Physiologyor Medicine',
#   'link': '/wiki/Michael_W._Young',
#   'name': u'Michael W. Young',
#   'year': 2017},
#  {'category': u'Literature',
#   'link': '/wiki/Kazuo_Ishiguro',
#   'name': u'Kazuo Ishiguro',
#   'year': 2017},
#  {'category': u'Peace',
#   'link': '/wiki/International_Campaign_to_Abolish_Nuclear_Weapons',
#   'name': u'International Campaign to Abolish Nuclear Weapons',
#   'year': 2017},
#  {'category': u'Economics',
#   'link': '/wiki/Richard_Thaler',
#   'name': u'Richard Thaler',
#   'year': 2017}]
